# %% [markdown]
# **Hitting API will give JSON file format**
# **use http://jsonviewer.stack.hu/ to view the API data in understandable format (paste the data in the  link and click on 'viewer' tab to view the file in JSON format)**

# %% [markdown]
# Extracting top rated movies from TMDB website
# User id - sudhanshu517
# mail id - shu*****@gmail.com
# pwd - A****pan***1997
#
# Keeping the following columns in dataframe - id, title, release_date, overview, popularity, vote_average, vote_count
# and have a total of 8851*7 size data

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
response.json()   # will show all the data but note in this whole dataset for each movie we only need data present inside "results" dictionary
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/90ez6ArvpO8bvpyIngBuwXOqJm5.jpg',
#    'genre_ids': [35, 18, 10749],
#    'id': 19404,
#    'original_language': 'hi',
#    'original_title': 'दिलवाले दुल्हनिया ले जायेंगे',
#    'overview': 'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fiancé. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.',
#    'popularity': 44.097,
#    'poster_path': '/2CAL2433ZeIihfX1Hb2139CX0pW.jpg',
#    'release_date': '1995-10-19',
#    'title': 'Dilwale Dulhania Le Jayenge',
#    'video': False,
#    'vote_average': 8.7,
#    'vote_count': 3761},
#   {'adult': False,
#    'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#    'genre_ids': [18, 80],
# ...

# %% [markdown]
# Extracting data from "result" dictionary

# %%
 response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/90ez6ArvpO8bvpyIngBuwXOqJm5.jpg',
#   'genre_ids': [35, 18, 10749],
#   'id': 19404,
#   'original_language': 'hi',
#   'original_title': 'दिलवाले दुल्हनिया ले जायेंगे',
#   'overview': 'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fiancé. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.',
#   'popularity': 44.097,
#   'poster_path': '/2CAL2433ZeIihfX1Hb2139CX0pW.jpg',
#   'release_date': '1995-10-19',
#   'title': 'Dilwale Dulhania Le Jayenge',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 3761},
#  {'adult': False,
#   'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
# ...

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df = pd.DataFrame()  # Creating an empty dataframe and will append data from all the pages (total of 428 pages , hence use range till 429)

# %%
for i in range(1,10): # here you can run thru 429 range since there are a total of 428 pages (starting from page 1) but we have kept it only till 10 here for quick processing of data
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)

# %%
df
# Out:
#         id                        title  \
# 0    19404  Dilwale Dulhania Le Jayenge
# 1      278     The Shawshank Redemption
# 2      238                The Godfather
# 3      424             Schindler's List
# 4      240        The Godfather Part II
# ..     ...                          ...
# 175    895                Andrei Rublev
# 176  68718             Django Unchained
# 177    996             Double Indemnity
# 178    500               Reservoir Dogs
# 179  55823                The Great War
#
#                                               overview release_date  \
# 0    Raj is a rich, carefree, happy-go-lucky second...   1995-10-19
# 1    Framed in the 1940s for the double murder of h...   1994-09-23
# 2    Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 3    The true story of how businessman Oskar Schind...   1993-12-15
# 4    In the continuing saga of the Corleone crime f...   1974-12-20
# ...

# %%
df.shape
# Out:
# (360, 7)

# %%
# Exporting the DataFrame into csv format
df.to_csv('movies.csv')
