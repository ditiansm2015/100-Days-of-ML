# %% [markdown]
# **Iterative imputer is also called MICE (Multivariate Imputation by Chained Equation)**
#
# **Concept** - Apply ML algos to predict missing values.
#
# The process is long (but simple).
#
# Use this video to understand the concept:
# https://youtu.be/a38ehxv3kyk
#
# Dataset has been uploaded on Git hub

# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression

# %%
df = np.round(pd.read_csv('50_Startups.csv')[['R&D Spend','Administration','Marketing Spend','Profit']]/10000)
np.random.seed(9)
df = df.sample(5)
df
# Out:
#     R&D Spend  Administration  Marketing Spend  Profit
# 21        8.0            15.0             30.0    11.0
# 37        4.0             5.0             20.0     9.0
# 2        15.0            10.0             41.0    19.0
# 14       12.0            16.0             26.0    13.0
# 44        2.0            15.0              3.0     7.0

# %%
df = df.iloc[:,0:-1]
df
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21        8.0            15.0             30.0
# 37        4.0             5.0             20.0
# 2        15.0            10.0             41.0
# 14       12.0            16.0             26.0
# 44        2.0            15.0              3.0

# %%
# We are creating some NaN (Missing values) in our dataset to work on this topic

df.iloc[1,0] = np.NaN
df.iloc[3,1] = np.NaN
df.iloc[-1,-1] = np.NaN
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
df.head()
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21        8.0            15.0             30.0
# 37        NaN             5.0             20.0
# 2        15.0            10.0             41.0
# 14       12.0             NaN             26.0
# 44        2.0            15.0              NaN

# %%
# Step 1 - Impute all missing values with mean of respective col

df0 = pd.DataFrame()

df0['R&D Spend'] = df['R&D Spend'].fillna(df['R&D Spend'].mean())
df0['Administration'] = df['Administration'].fillna(df['Administration'].mean())
df0['Marketing Spend'] = df['Marketing Spend'].fillna(df['Marketing Spend'].mean())

# %%
# 0th Iteration
df0
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00           15.00            30.00
# 37       9.25            5.00            20.00
# 2       15.00           10.00            41.00
# 14      12.00           11.25            26.00
# 44       2.00           15.00            29.25

# %%
# Remove the col1 imputed value
df1 = df0.copy()

df1.iloc[1,0] = np.NaN

df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21        8.0           15.00            30.00
# 37        NaN            5.00            20.00
# 2        15.0           10.00            41.00
# 14       12.0           11.25            26.00
# 44        2.0           15.00            29.25

# %%
# Use first 3 rows to build a model and use the last for prediction

X = df1.iloc[[0,2,3,4],1:3]
X
# Out:
#     Administration  Marketing Spend
# 21           15.00            30.00
# 2            10.00            41.00
# 14           11.25            26.00
# 44           15.00            29.25

# %%
y = df1.iloc[[0,2,3,4],0]
y
# Out:
# 21     8.0
# 2     15.0
# 14    12.0
# 44     2.0
# Name: R&D Spend, dtype: float64

# %%
lr = LinearRegression()
lr.fit(X,y)
lr.predict(df1.iloc[1,1:].values.reshape(1,2))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([23.14158651])

# %%
df1.iloc[1,0] = 23.14

# %%
df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00           15.00            30.00
# 37      23.14            5.00            20.00
# 2       15.00           10.00            41.00
# 14      12.00           11.25            26.00
# 44       2.00           15.00            29.25

# %%
# Remove the col2 imputed value

df1.iloc[3,1] = np.NaN

df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00            15.0            30.00
# 37      23.14             5.0            20.00
# 2       15.00            10.0            41.00
# 14      12.00             NaN            26.00
# 44       2.00            15.0            29.25

# %%
# Use last 3 rows to build a model and use the first for prediction
X = df1.iloc[[0,1,2,4],[0,2]]
X
# Out:
#     R&D Spend  Marketing Spend
# 21       8.00            30.00
# 37      23.14            20.00
# 2       15.00            41.00
# 44       2.00            29.25

# %%
y = df1.iloc[[0,1,2,4],1]
y
# Out:
# 21    15.0
# 37     5.0
# 2     10.0
# 44    15.0
# Name: Administration, dtype: float64

# %%
lr = LinearRegression()
lr.fit(X,y)
lr.predict(df1.iloc[3,[0,2]].values.reshape(1,2))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([11.06331285])

# %%
df1.iloc[3,1] = 11.06

# %%
df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00           15.00            30.00
# 37      23.14            5.00            20.00
# 2       15.00           10.00            41.00
# 14      12.00           11.06            26.00
# 44       2.00           15.00            29.25

# %%
# Remove the col3 imputed value
df1.iloc[4,-1] = np.NaN

df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00           15.00             30.0
# 37      23.14            5.00             20.0
# 2       15.00           10.00             41.0
# 14      12.00           11.06             26.0
# 44       2.00           15.00              NaN

# %%
# Use last 3 rows to build a model and use the first for prediction
X = df1.iloc[0:4,0:2]
X
# Out:
#     R&D Spend  Administration
# 21       8.00           15.00
# 37      23.14            5.00
# 2       15.00           10.00
# 14      12.00           11.06

# %%
y = df1.iloc[0:4,-1]
y
# Out:
# 21    30.0
# 37    20.0
# 2     41.0
# 14    26.0
# Name: Marketing Spend, dtype: float64

# %%
lr = LinearRegression()
lr.fit(X,y)
lr.predict(df1.iloc[4,0:2].values.reshape(1,2))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([31.56351448])

# %%
df1.iloc[4,-1] = 31.56

# %%
# After 1st Iteration
df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00           15.00            30.00
# 37      23.14            5.00            20.00
# 2       15.00           10.00            41.00
# 14      12.00           11.06            26.00
# 44       2.00           15.00            31.56

# %%
# Subtract 0th iteration from 1st iteration

df1 - df0
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       0.00            0.00             0.00
# 37      13.89            0.00             0.00
# 2        0.00            0.00             0.00
# 14       0.00           -0.19             0.00
# 44       0.00            0.00             2.31

# %%
df2 = df1.copy()

df2.iloc[1,0] = np.NaN

df2
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21        8.0           15.00            30.00
# 37        NaN            5.00            20.00
# 2        15.0           10.00            41.00
# 14       12.0           11.06            26.00
# 44        2.0           15.00            31.56

# %%
X = df2.iloc[[0,2,3,4],1:3]
y = df2.iloc[[0,2,3,4],0]

lr = LinearRegression()
lr.fit(X,y)
lr.predict(df2.iloc[1,1:].values.reshape(1,2))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([23.78627207])

# %%
df2.iloc[1,0] = 23.78

# %%
df2.iloc[3,1] = np.NaN
X = df2.iloc[[0,1,2,4],[0,2]]
y = df2.iloc[[0,1,2,4],1]

lr = LinearRegression()
lr.fit(X,y)
lr.predict(df2.iloc[3,[0,2]].values.reshape(1,2))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([11.22020174])

# %%
df2.iloc[3,1] = 11.22

# %%
df2.iloc[4,-1] = np.NaN

X = df2.iloc[0:4,0:2]
y = df2.iloc[0:4,-1]

lr = LinearRegression()
lr.fit(X,y)
lr.predict(df2.iloc[4,0:2].values.reshape(1,2))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([38.87979054])

# %%
df2.iloc[4,-1] = 31.56

# %%
df2
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00           15.00            30.00
# 37      23.78            5.00            20.00
# 2       15.00           10.00            41.00
# 14      12.00           11.22            26.00
# 44       2.00           15.00            31.56

# %%
df2 - df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       0.00            0.00              0.0
# 37       0.64            0.00              0.0
# 2        0.00            0.00              0.0
# 14       0.00            0.16              0.0
# 44       0.00            0.00              0.0

# %%
df3 = df2.copy()

df3.iloc[1,0] = np.NaN

df3
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21        8.0           15.00            30.00
# 37        NaN            5.00            20.00
# 2        15.0           10.00            41.00
# 14       12.0           11.22            26.00
# 44        2.0           15.00            31.56

# %%
X = df3.iloc[[0,2,3,4],1:3]
y = df3.iloc[[0,2,3,4],0]

lr = LinearRegression()
lr.fit(X,y)
lr.predict(df3.iloc[1,1:].values.reshape(1,2))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([24.57698058])

# %%
df3.iloc[1,0] = 24.57

# %%
df3.iloc[3,1] = 11.37

# %%
df3.iloc[4,-1] = np.NaN

X = df3.iloc[0:4,0:2]
y = df3.iloc[0:4,-1]

lr = LinearRegression()
lr.fit(X,y)
lr.predict(df3.iloc[4,0:2].values.reshape(1,2))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([45.53976417])

# %%
df3.iloc[4,-1] = 45.53

# %%
df2.iloc[3,1] = 11.22

# %%
df3
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00           15.00            30.00
# 37      24.57            5.00            20.00
# 2       15.00           10.00            41.00
# 14      12.00           11.37            26.00
# 44       2.00           15.00            45.53

# %%
df3 - df2
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       0.00            0.00             0.00
# 37       0.79            0.00             0.00
# 2        0.00            0.00             0.00
# 14       0.00            0.15             0.00
# 44       0.00            0.00            13.97
